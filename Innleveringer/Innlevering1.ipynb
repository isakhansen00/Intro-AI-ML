# %%
import random

# %%
r = random.random()

# %%
r
# Out:
# 0.10085276725798842

# %%
type(r)
# Out:
# float

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
rnd = np.random.uniform(-5, 5, (1000,2))

# %%
plt.scatter(rnd[:,1] + np.sin(rnd[:,0]), rnd[:,1] - np.cos(rnd[:,1]))

# %%
print("Isak Steinmo Hansen")
# Out:
# Isak Steinmo Hansen
